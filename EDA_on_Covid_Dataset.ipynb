# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/EDA/blob/main/EDA_on_Covid_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"/content/Covid Dataset.xlsx",na_values=["NaT"])

# %%
df.head()
# Out:
#    OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0       1          38.3           $200,000+        Masters degree
# 1       2          34.6           $200,000+  Undergraduate degree
# 2       3          34.3  $100,000 -$124,999  Undergraduate degree
# 3       4          28.8  $100,000 -$124,999        Masters degree
# 4       5          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                 2020-12-01
# 1                       NaN                                        NaT
# ...

# %%
df.shape
# Out:
# (10772, 16)

# %%
df.describe()
# Out:
#              OSF_ID  Maternal_Age  Edinburgh_Postnatal_Depression_Scale  \
# count  10772.000000  10661.000000                           9598.000000
# mean    5386.500000     31.844602                             10.194832
# min        1.000000     17.000000                              0.000000
# 25%     2693.750000     28.900000                              6.000000
# 50%     5386.500000     31.800000                             10.000000
# 75%     8079.250000     34.800000                             14.000000
# max    10772.000000     49.700000                             30.000000
# std     3109.752884      4.422368                              5.505230
#
#        PROMIS_Anxiety  Gestational_Age_At_Birth  \
# count     9566.000000               6734.000000
# mean        18.677713                 39.342241
# min          7.000000                 24.860000
# 25%         14.000000                 38.570000
# 50%         19.000000                 39.570000
# ...

# %%
df.drop(columns=["OSF_ID","Language"],inplace=True)

# %%
rows_to_drop=df[df["Maternal_Age"]<21].index

# %%
df.drop(rows_to_drop,inplace=True)

# %%
df.shape
# Out:
# (10681, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10681 entries, 0 to 10771
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10570 non-null  float64
#  1   Household_Income                            10432 non-null  object
#  2   Maternal_Education                          10504 non-null  object
#  3   Edinburgh_Postnatal_Depression_Scale        9523 non-null   float64
#  4   PROMIS_Anxiety                              9491 non-null   float64
#  5   Gestational_Age_At_Birth                    6707 non-null   float64
#  6   Delivery_Date(converted to month and year)  6706 non-null   datetime64[ns]
#  7   Birth_Length                                5460 non-null   float64
#  8   Birth_Weight                                6054 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# count  10570.000000                           9523.000000     9491.000000
# mean      31.949130                             10.164549       18.651670
# min       21.100000                              0.000000        7.000000
# 25%       29.000000                              6.000000       14.000000
# 50%       31.800000                             10.000000       19.000000
# 75%       34.800000                             14.000000       23.000000
# max       49.700000                             30.000000       35.000000
# std        4.294025                              5.489647        6.077081
#
#        Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# count               6707.000000                                       6706
# mean                  39.341846              2020-11-17 01:43:55.848493824
# min                   24.860000                        2020-04-01 00:00:00
# ...

# %%
df.head(7)
# Out:
#    Maternal_Age     Household_Income    Maternal_Education  \
# 0          38.3            $200,000+        Masters degree
# 1          34.6            $200,000+  Undergraduate degree
# 2          34.3   $100,000 -$124,999  Undergraduate degree
# 3          28.8   $100,000 -$124,999        Masters degree
# 4          36.5      $40,000-$69,999  Undergraduate degree
# 5          38.3  $150,000 - $174,999  Undergraduate degree
# 6          34.5            $200,000+   High school diploma
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
# 5                                   3.0             8.0
# 6                                   8.0            15.0
#
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Maternal_Age                                   1.039229
# Household_Income                               2.331242
# Maternal_Education                             1.657148
# Edinburgh_Postnatal_Depression_Scale          10.841681
# PROMIS_Anxiety                                11.141279
# Gestational_Age_At_Birth                      37.206254
# Delivery_Date(converted to month and year)    37.215617
# Birth_Length                                  48.881191
# Birth_Weight                                  43.319914
# Delivery_Mode                                 48.347533
# NICU_Stay                                     48.375620
# Threaten_Life                                  8.267016
# Threaten_Baby_Danger                           8.351278
# Threaten_Baby_Harm                             8.238929
# dtype: float64

# %%
df.to_csv("Covid .csv",index=False)

# %%
new_df=pd.read_csv("/content/Covid .csv",na_values=["NaT"])

# %%
new_df.head(5)
# Out:
#    Maternal_Age    Household_Income    Maternal_Education  \
# 0          38.3           $200,000+        Masters degree
# 1          34.6           $200,000+  Undergraduate degree
# 2          34.3  $100,000 -$124,999  Undergraduate degree
# 3          28.8  $100,000 -$124,999        Masters degree
# 4          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                 2020-12-01
# 1                       NaN                                        NaN
# ...

# %%
rows_drp=new_df[(new_df["Edinburgh_Postnatal_Depression_Scale"].isnull())&(new_df["PROMIS_Anxiety"].isnull())&(new_df["Birth_Length"].isnull())&(new_df["Birth_Weight"].isnull())&(new_df["Delivery_Mode"].isnull())&(new_df["Threaten_Baby_Danger"].isnull())].index

# %%
new_df.drop(rows_drp,inplace=True)

# %%
new_df.shape
# Out:
# (10084, 14)

# %%
new_df.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
new_df.isnull().sum()/new_df.shape[0]*100
# Out:
# Maternal_Age                                   0.614835
# Household_Income                               1.705672
# Maternal_Education                             1.219754
# Edinburgh_Postnatal_Depression_Scale           5.563269
# PROMIS_Anxiety                                 5.880603
# Gestational_Age_At_Birth                      34.500198
# Delivery_Date(converted to month and year)    34.510115
# Birth_Length                                  45.854820
# Birth_Weight                                  39.964300
# Delivery_Mode                                 45.289568
# NICU_Stay                                     45.319318
# Threaten_Life                                  3.024593
# Threaten_Baby_Danger                           2.925426
# Threaten_Baby_Harm                             2.975010
# dtype: float64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10084 entries, 0 to 10680
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10022 non-null  float64
#  1   Household_Income                            9912 non-null   object
#  2   Maternal_Education                          9961 non-null   object
#  3   Edinburgh_Postnatal_Depression_Scale        9523 non-null   float64
#  4   PROMIS_Anxiety                              9491 non-null   float64
#  5   Gestational_Age_At_Birth                    6605 non-null   float64
#  6   Delivery_Date(converted to month and year)  6604 non-null   object
#  7   Birth_Length                                5460 non-null   float64
#  8   Birth_Weight                                6054 non-null   float64
# ...

# %%
numerical_columns=new_df.select_dtypes(include=["number"])

# %%
numerical_columns
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0              38.3                                   9.0            13.0
# 1              34.6                                   4.0            17.0
# 3              28.8                                   9.0            20.0
# 4              36.5                                  14.0            20.0
# 5              38.3                                   3.0             8.0
# ...             ...                                   ...             ...
# 10675          32.7                                  15.0            27.0
# 10676          38.3                                  10.0            18.0
# 10678          27.7                                   4.0            15.0
# 10679          23.0                                  12.0            19.0
# 10680          34.6                                  18.0            30.0
#
#        Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# ...

# %%
for i,predictor in enumerate(numerical_columns.columns):
  plt.figure(i)
  sns.histplot(data=new_df,x=predictor,kde=True)

# %%
categorical_columns=new_df.select_dtypes(exclude=["number"])

# %%
categorical_columns
# Out:
#           Household_Income    Maternal_Education  \
# 0                $200,000+        Masters degree
# 1                $200,000+  Undergraduate degree
# 3       $100,000 -$124,999        Masters degree
# 4          $40,000-$69,999  Undergraduate degree
# 5      $150,000 - $174,999  Undergraduate degree
# ...                    ...                   ...
# 10675      $70,000-$99,999   High school diploma
# 10676   $100,000 -$124,999  Undergraduate degree
# 10678     $20,000- $39,999  College/trade school
# 10679     $20,000- $39,999  College/trade school
# 10680      $70,000-$99,999        Masters degree
#
#       Delivery_Date(converted to month and year)  \
# 0                                     2020-12-01
# 1                                            NaN
# 3                                     2020-12-01
# 4                                     2020-10-01
# 5                                     2020-06-01
# ...                                          ...
# ...

# %%
for i in categorical_columns.columns:
  display(new_df[i].value_counts())
# Out:
# Household_Income
# $70,000-$99,999        1980
# $100,000 -$124,999     1866
# $40,000-$69,999        1315
# $125,000- $149,999     1307
# $150,000 - $174,999    1109
# $200,000+               973
# $175,000- $199,999      641
# $20,000- $39,999        536
# Less than $20, 000      185
# Name: count, dtype: int64
# Maternal_Education
# Undergraduate degree             3943
# College/trade school             2547
# Masters degree                   1838
# High school diploma               775
# Doctoral Degree                   760
# Less than high school diploma      98
# Name: count, dtype: int64
# Delivery_Date(converted to month and year)
# 2020-08-01    668
# 2020-09-01    628
# 2020-07-01    614
# 2020-10-01    608
# 2020-06-01    503
# 2020-11-01    465
# 2021-01-01    405
# 2020-12-01    394
# 2021-03-01    381
# 2021-04-01    333
# 2021-02-01    306
# 2021-05-01    286
# 2021-06-01    274
# 2020-05-01    211
# 2021-07-01    208
# 2021-08-01    134
# 2021-09-01     84
# ...

# %%
new_df.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
new_df["Gestational_Age_At_Birth"]=np.round(new_df["Gestational_Age_At_Birth"]/4.33,2)

# %%
new_df
# Out:
#        Maternal_Age     Household_Income    Maternal_Education  \
# 0              38.3            $200,000+        Masters degree
# 1              34.6            $200,000+  Undergraduate degree
# 3              28.8   $100,000 -$124,999        Masters degree
# 4              36.5      $40,000-$69,999  Undergraduate degree
# 5              38.3  $150,000 - $174,999  Undergraduate degree
# ...             ...                  ...                   ...
# 10675          32.7      $70,000-$99,999   High school diploma
# 10676          38.3   $100,000 -$124,999  Undergraduate degree
# 10678          27.7     $20,000- $39,999  College/trade school
# 10679          23.0     $20,000- $39,999  College/trade school
# 10680          34.6      $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
def healthy_height(row):
  if pd.isnull(row["Birth_Length"]):
    return "Data Missing"
  elif row["Birth_Length"]>39 and row["Birth_Length"]<61:
    return "Healthy"
  else:
    "Unhealthy"
new_df["Height"]=new_df.apply(healthy_height,axis=1)

# %%
def healthy_weight(row):
  if pd.isnull(row["Birth_Weight"]):
    return "Data Missing"
  elif row["Birth_Weight"]>2550 and row["Birth_Weight"]<4000:
    return "Healthy"
  else:
    "Unhealthy"
new_df["Weight"]=new_df.apply(healthy_weight,axis=1)

# %%
new_df
# Out:
#        Maternal_Age     Household_Income    Maternal_Education  \
# 0              38.3            $200,000+        Masters degree
# 1              34.6            $200,000+  Undergraduate degree
# 3              28.8   $100,000 -$124,999        Masters degree
# 4              36.5      $40,000-$69,999  Undergraduate degree
# 5              38.3  $150,000 - $174,999  Undergraduate degree
# ...             ...                  ...                   ...
# 10675          32.7      $70,000-$99,999   High school diploma
# 10676          38.3   $100,000 -$124,999  Undergraduate degree
# 10678          27.7     $20,000- $39,999  College/trade school
# 10679          23.0     $20,000- $39,999  College/trade school
# 10680          34.6      $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
new_df.tail()
# Out:
#        Maternal_Age    Household_Income    Maternal_Education  \
# 10675          32.7     $70,000-$99,999   High school diploma
# 10676          38.3  $100,000 -$124,999  Undergraduate degree
# 10678          27.7    $20,000- $39,999  College/trade school
# 10679          23.0    $20,000- $39,999  College/trade school
# 10680          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 10675                                  15.0            27.0
# 10676                                  10.0            18.0
# 10678                                   4.0            15.0
# 10679                                  12.0            19.0
# 10680                                  18.0            30.0
#
#        Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 10675                       NaN                                        NaN
# 10676                       NaN                                        NaN
# ...

# %%
numerical_columns=new_df.select_dtypes(include=["number"])

# %%
numerical_columns
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0              38.3                                   9.0            13.0
# 1              34.6                                   4.0            17.0
# 3              28.8                                   9.0            20.0
# 4              36.5                                  14.0            20.0
# 5              38.3                                   3.0             8.0
# ...             ...                                   ...             ...
# 10675          32.7                                  15.0            27.0
# 10676          38.3                                  10.0            18.0
# 10678          27.7                                   4.0            15.0
# 10679          23.0                                  12.0            19.0
# 10680          34.6                                  18.0            30.0
#
#        Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# ...

# %%
for i,z in enumerate(new_df.columns):
  plt.figure(i)
  sns.lineplot(data=new_df,x="Maternal_Age",y=z)

# %%
temp_df=new_df[new_df["Delivery_Mode"].notnull()]

# %%
temp_df.shape
# Out:
# (5517, 16)

# %%
new_df.shape
# Out:
# (10084, 16)

# %%
temp_df=temp_df[["Maternal_Age","Delivery_Mode"]]

# %%
temp_df=temp_df[temp_df["Maternal_Age"].notnull()]

# %%
temp_df
# Out:
#        Maternal_Age                  Delivery_Mode
# 0              38.3                      Vaginally
# 3              28.8                      Vaginally
# 4              36.5  Caesarean-section (c-section)
# 8              33.1                      Vaginally
# 11             29.5  Caesarean-section (c-section)
# ...             ...                            ...
# 10664          41.7  Caesarean-section (c-section)
# 10665          27.8  Caesarean-section (c-section)
# 10666          36.2                      Vaginally
# 10670          33.2                      Vaginally
# 10672          24.0                      Vaginally
#
# [5502 rows x 2 columns]

# %%
def healthy_age(row):
  if row["Maternal_Age"]<=23:
    return "UnderAge"
  elif row["Maternal_Age"]>=24 and row["Maternal_Age"]<=30:
    return "Healthy"
  else:
    return "OldAge"
temp_df["Age_Condition"]=temp_df.apply(healthy_age,axis=1)

# %%
temp_df
# Out:
#        Maternal_Age                  Delivery_Mode Age_Condition
# 0              38.3                      Vaginally        OldAge
# 3              28.8                      Vaginally       Healthy
# 4              36.5  Caesarean-section (c-section)        OldAge
# 8              33.1                      Vaginally        OldAge
# 11             29.5  Caesarean-section (c-section)       Healthy
# ...             ...                            ...           ...
# 10664          41.7  Caesarean-section (c-section)        OldAge
# 10665          27.8  Caesarean-section (c-section)       Healthy
# 10666          36.2                      Vaginally        OldAge
# 10670          33.2                      Vaginally        OldAge
# 10672          24.0                      Vaginally       Healthy
#
# [5502 rows x 3 columns]

# %%
temp_df.groupby("Age_Condition")["Delivery_Mode"].value_counts().reset_index()
# Out:
#   Age_Condition                  Delivery_Mode  count
# 0       Healthy                      Vaginally   1069
# 1       Healthy  Caesarean-section (c-section)    347
# 2        OldAge                      Vaginally   2780
# 3        OldAge  Caesarean-section (c-section)   1267
# 4      UnderAge                      Vaginally     29
# 5      UnderAge  Caesarean-section (c-section)     10

# %%
stay=new_df[["Maternal_Age","NICU_Stay"]]

# %%
new_df.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm', 'Height', 'Weight'],
#       dtype='object')

# %%
stay=stay[stay["NICU_Stay"].notnull()]

# %%
stay=stay[stay["Maternal_Age"].notnull()]

# %%
stay
# Out:
#        Maternal_Age NICU_Stay
# 0              38.3        No
# 3              28.8        No
# 4              36.5        No
# 8              33.1        No
# 11             29.5        No
# ...             ...       ...
# 10664          41.7        No
# 10665          27.8        No
# 10666          36.2        No
# 10670          33.2        No
# 10672          24.0        No
#
# [5499 rows x 2 columns]

# %%
sns.lineplot(data=stay,x="Maternal_Age",y="NICU_Stay")
# Out:
# <Axes: xlabel='Maternal_Age', ylabel='NICU_Stay'>

# %%
temp_df
# Out:
#        Maternal_Age                  Delivery_Mode Age_Condition
# 0              38.3                      Vaginally        OldAge
# 3              28.8                      Vaginally       Healthy
# 4              36.5  Caesarean-section (c-section)        OldAge
# 8              33.1                      Vaginally        OldAge
# 11             29.5  Caesarean-section (c-section)       Healthy
# ...             ...                            ...           ...
# 10664          41.7  Caesarean-section (c-section)        OldAge
# 10665          27.8  Caesarean-section (c-section)       Healthy
# 10666          36.2                      Vaginally        OldAge
# 10670          33.2                      Vaginally        OldAge
# 10672          24.0                      Vaginally       Healthy
#
# [5502 rows x 3 columns]

# %%
new_df.columns
# Out:
# Index(['Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Threaten_Life',
#        'Threaten_Baby_Danger', 'Threaten_Baby_Harm', 'Height', 'Weight'],
#       dtype='object')

# %%
w=new_df[["PROMIS_Anxiety","Household_Income"]]

# %%
t=new_df[["Edinburgh_Postnatal_Depression_Scale","Household_Income"]]

# %%
import plotly.express as px
px.histogram(w,x="PROMIS_Anxiety",color="Household_Income",hover_data=w)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(t,x="Edinburgh_Postnatal_Depression_Scale",color="Household_Income",hover_data=t)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp=new_df[["Threaten_Life","Household_Income"]]
temp
# Out:
#        Threaten_Life     Household_Income
# 0                2.0            $200,000+
# 1                2.0            $200,000+
# 3               53.0   $100,000 -$124,999
# 4               23.0      $40,000-$69,999
# 5               29.0  $150,000 - $174,999
# ...              ...                  ...
# 10675           54.0      $70,000-$99,999
# 10676           54.0   $100,000 -$124,999
# 10678           21.0     $20,000- $39,999
# 10679           65.0     $20,000- $39,999
# 10680           84.0      $70,000-$99,999
#
# [10084 rows x 2 columns]

# %%
temp.groupby("Household_Income")["Threaten_Life"].mean().reset_index().sort_values(by="Threaten_Life",ascending=False)
# Out:
#       Household_Income  Threaten_Life
# 8   Less than $20, 000      49.989071
# 4     $20,000- $39,999      47.762906
# 6      $40,000-$69,999      45.315175
# 7      $70,000-$99,999      42.429014
# 0   $100,000 -$124,999      41.828883
# 2  $150,000 - $174,999      41.392463
# 1   $125,000- $149,999      40.517969
# 3   $175,000- $199,999      40.062300
# 5            $200,000+      39.463874

# %%
tem=new_df[["Threaten_Baby_Danger","Household_Income"]]
tem
# Out:
#        Threaten_Baby_Danger     Household_Income
# 0                       3.0            $200,000+
# 1                      33.0            $200,000+
# 3                      67.0   $100,000 -$124,999
# 4                      32.0      $40,000-$69,999
# 5                      36.0  $150,000 - $174,999
# ...                     ...                  ...
# 10675                  64.0      $70,000-$99,999
# 10676                  62.0   $100,000 -$124,999
# 10678                  93.0     $20,000- $39,999
# 10679                  94.0     $20,000- $39,999
# 10680                  73.0      $70,000-$99,999
#
# [10084 rows x 2 columns]

# %%
tem.groupby("Household_Income")["Threaten_Baby_Danger"].mean().reset_index().sort_values(by="Threaten_Baby_Danger",ascending=False)
# Out:
#       Household_Income  Threaten_Baby_Danger
# 8   Less than $20, 000             59.407609
# 4     $20,000- $39,999             58.005736
# 6      $40,000-$69,999             53.775019
# 7      $70,000-$99,999             51.998967
# 0   $100,000 -$124,999             50.320261
# 1   $125,000- $149,999             48.904762
# 2  $150,000 - $174,999             48.456382
# 3   $175,000- $199,999             46.923200
# 5            $200,000+             46.885057

# %%
te=new_df[["Threaten_Baby_Harm","Household_Income"]]
te
# Out:
#        Threaten_Baby_Harm     Household_Income
# 0                    27.0            $200,000+
# 1                    92.0            $200,000+
# 3                    54.0   $100,000 -$124,999
# 4                    71.0      $40,000-$69,999
# 5                    33.0  $150,000 - $174,999
# ...                   ...                  ...
# 10675                75.0      $70,000-$99,999
# 10676                74.0   $100,000 -$124,999
# 10678                76.0     $20,000- $39,999
# 10679                94.0     $20,000- $39,999
# 10680                94.0      $70,000-$99,999
#
# [10084 rows x 2 columns]

# %%
te.groupby("Household_Income")["Threaten_Baby_Harm"].mean().reset_index().sort_values(by="Threaten_Baby_Harm",ascending=False)
# Out:
#       Household_Income  Threaten_Baby_Harm
# 4     $20,000- $39,999           66.596558
# 8   Less than $20, 000           65.434783
# 7      $70,000-$99,999           63.587810
# 6      $40,000-$69,999           63.421134
# 0   $100,000 -$124,999           62.382561
# 1   $125,000- $149,999           62.018750
# 3   $175,000- $199,999           60.517572
# 5            $200,000+           60.134937
# 2  $150,000 - $174,999           59.960514

# %% [markdown]
# CONCLUSIONS
#
# It is evident from the observations that individuals living below the poverty line ($70,000) are significantly more susceptible to anxiety and EPDS (Edinburgh Postnatal Depression Scale) scores. Within this income bracket, nearly 70% of the population has been diagnosed with anxiety and depression, exacerbated by the conditions brought on by the COVID-19 pandemic.
#
# There is a positive correlation between increased income and reduced probability of anxiety and depression. High-income individuals have approximately a 33% chance of being diagnosed with anxiety and depression due to COVID-19, indicating a substantial mental health benefit associated with higher income levels.
#
# The COVID-19 pandemic has had a profoundly adverse impact on low-income families, particularly those below the survival line. The shortage of income has heightened their worries about the well-being of their children and women. Families below the survival line exhibit a very high threatening score for women, with an average score of 51/100. In contrast, as income levels rise, concerns diminish, likely due to better access to healthcare facilities for higher-income families.
#
# Unlike the varying threatening scores for women across income levels, the concern for the impact of COVID-19 on newborns is universal. Regardless of income, all categories show significant worry about potential harm and damage to newborns, which may contribute to high anxiety levels in pregnant women during the pandemic.

# %%
t=new_df[["PROMIS_Anxiety","Birth_Weight","Gestational_Age_At_Birth"]]

# %%
for i in t.columns:
  plt.figure(i)
  sns.lineplot(data=t,x=new_df['Edinburgh_Postnatal_Depression_Scale'],y=i,color="red")

# %%
q=new_df[["Weight","Height","NICU_Stay"]]

# %%
new_df["NICU_Stay"].fillna("Data Missing",inplace=True)
# Out:
# <ipython-input-125-b158831c85ba>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
q
# Out:
#              Weight        Height     NICU_Stay
# 0           Healthy       Healthy            No
# 1      Data Missing  Data Missing  Data Missing
# 3              None       Healthy            No
# 4           Healthy       Healthy            No
# 5      Data Missing  Data Missing  Data Missing
# ...             ...           ...           ...
# 10675  Data Missing  Data Missing  Data Missing
# 10676  Data Missing  Data Missing  Data Missing
# 10678  Data Missing  Data Missing  Data Missing
# 10679  Data Missing  Data Missing  Data Missing
# 10680          None  Data Missing  Data Missing
#
# [10084 rows x 3 columns]

# %%
for i in q.columns:
  plt.figure(i)
  sns.lineplot(data=q,x=new_df["Delivery_Mode"],y=i,color="red")

# %%
new_df.shape
# Out:
# (10084, 16)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10084 entries, 0 to 10680
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10022 non-null  float64
#  1   Household_Income                            9912 non-null   object
#  2   Maternal_Education                          9961 non-null   object
#  3   Edinburgh_Postnatal_Depression_Scale        9523 non-null   float64
#  4   PROMIS_Anxiety                              9491 non-null   float64
#  5   Gestational_Age_At_Birth                    6605 non-null   float64
#  6   Delivery_Date(converted to month and year)  6604 non-null   object
#  7   Birth_Length                                5460 non-null   float64
#  8   Birth_Weight                                6054 non-null   float64
# ...

# %%
c=new_df[new_df["Weight"].notnull()]

# %%
d=c[c["Height"].notnull()]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8947 entries, 0 to 10679
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                8896 non-null   float64
#  1   Household_Income                            8806 non-null   object
#  2   Maternal_Education                          8845 non-null   object
#  3   Edinburgh_Postnatal_Depression_Scale        8460 non-null   float64
#  4   PROMIS_Anxiety                              8429 non-null   float64
#  5   Gestational_Age_At_Birth                    5468 non-null   float64
#  6   Delivery_Date(converted to month and year)  5467 non-null   object
#  7   Birth_Length                                4430 non-null   float64
#  8   Birth_Weight                                4917 non-null   float64
# ...

# %%
e=d[d["NICU_Stay"].notnull()]

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8947 entries, 0 to 10679
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                8896 non-null   float64
#  1   Household_Income                            8806 non-null   object
#  2   Maternal_Education                          8845 non-null   object
#  3   Edinburgh_Postnatal_Depression_Scale        8460 non-null   float64
#  4   PROMIS_Anxiety                              8429 non-null   float64
#  5   Gestational_Age_At_Birth                    5468 non-null   float64
#  6   Delivery_Date(converted to month and year)  5467 non-null   object
#  7   Birth_Length                                4430 non-null   float64
#  8   Birth_Weight                                4917 non-null   float64
# ...

# %%
for i in e.columns:
  plt.figure(i)
  sns.lineplot(data=e,x=e["Delivery_Mode"],y=i,color="red")
